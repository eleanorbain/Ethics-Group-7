# %% [markdown]
# ##Python Imports

# %%
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

# %% [markdown]
# ## Model

# %%
#3 layers with 128 3x3 filters
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model.compile(optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 222s 236ms/step - accuracy: 0.8952 - loss: 0.3183
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 260s 233ms/step - accuracy: 0.9880 - loss: 0.0378
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 218s 233ms/step - accuracy: 0.9929 - loss: 0.0227
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 222s 236ms/step - accuracy: 0.9952 - loss: 0.0163
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 223s 238ms/step - accuracy: 0.9963 - loss: 0.0132

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9901 - loss: 0.0321
# Test accuracy: 0.993
